# %%
import json

# %%
hardwares = []
with open('hardwares.json', 'r') as f:
    hardwares = json.load(f)

# %%
hardwares
# Out:
# [{'gpu': '2-WAY SLI 1080TI FE', 'cpu': 'CORE I3 8100'},
#  {'gpu': '2-WAY SLI 1080TI FE', 'cpu': 'CORE I5 8400'},
#  {'gpu': '2-WAY SLI 1080TI FE', 'cpu': 'CORE I7 8700'},
#  {'gpu': '2-WAY SLI 980TI', 'cpu': 'CORE I3 8100'},
#  {'gpu': '2-WAY SLI 980TI', 'cpu': 'CORE I5 8400'},
#  {'gpu': '2-WAY SLI 980TI', 'cpu': 'CORE I7 8700'},
#  {'gpu': 'AMD R9 Fury X', 'cpu': 'CORE I3 8100'},
#  {'gpu': 'AMD R9 Fury X', 'cpu': 'CORE I5 8400'},
#  {'gpu': 'AMD R9 Fury X', 'cpu': 'CORE I7 8700'},
#  {'gpu': 'AMD RADEON PRO DUO', 'cpu': 'CORE I5 8400'},
#  {'gpu': 'AMD RADEON PRO DUO', 'cpu': 'CORE I7 8700'},
#  {'gpu': 'AMD RADEON R9 295X2', 'cpu': 'CORE I5 8400'},
#  {'gpu': 'AMD RADEON R9 295X2', 'cpu': 'CORE I7 8700'},
#  {'gpu': 'GT 1030', 'cpu': 'CORE I3 8100'},
#  {'gpu': 'GT 1030', 'cpu': 'CORE I5 8400'},
#  {'gpu': 'GT 1030', 'cpu': 'CORE I7 8700'},
#  {'gpu': 'GTX 1050', 'cpu': 'CORE I3 8100'},
#  {'gpu': 'GTX 1050', 'cpu': 'CORE I5 7400'},
# ...

# %%
gpus = set(map(lambda i: i['gpu'], hardwares))
cpus = set(map(lambda i: i['cpu'], hardwares))

# %%
gpus
# Out:
# {'2-WAY SLI 1080TI FE',
#  '2-WAY SLI 980TI',
#  'AMD R9 Fury X',
#  'AMD RADEON PRO DUO',
#  'AMD RADEON R9 295X2',
#  'GT 1030',
#  'GTX 1050',
#  'GTX 1050 Ti',
#  'GTX 1060 3GB',
#  'GTX 1060 6GB',
#  'GTX 1060 6GB PCYES',
#  'GTX 1070 HOF',
#  'GTX 1070 Ti FE',
#  'GTX 1080 FE',
#  'GTX 1080 HOF',
#  'GTX 1080 TI FE',
#  'GTX 1080 Ti SC2',
#  'GTX 1650',
#  'GTX 1660',
#  'GTX 1660 SUPER',
#  'GTX 1660TI',
#  'GTX 1660TI PCYES',
#  'GTX 660',
#  'GTX 750 Ti',
#  'GTX 760 4GB',
#  'GTX 770',
#  'GTX 950 FTW',
#  'GTX 960 2GB',
#  'GTX 960 4GB',
#  'GTX 970 Hybrid',
#  'GTX 980 G1 Gaming',
#  'GTX 980 Ti',
#  'GTX 980 Ti Hybrid',
#  'GTX Titan X (Hybrid)',
#  'RTX 2060 6GB FE',
#  'RTX 2060 PCYES',
#  'RTX 2060 SUPER FE',
#  'RTX 2070',
#  'RTX 2070 SUPER FE',
#  'RTX 2070 SUPER PCYES',
#  'RTX 2080 FE',
#  'RTX 2080 SUPER FE',
#  'RTX 2080 TI FE',
#  'RTX 3060 TI FE',
#  'RTX 3070 FE',
#  'RTX 3070 GAINWARD',
#  'RTX 3070 PCYES',
#  'RTX 3070 TI SG GALAX',
#  'RTX 3080 FE',
# ...

# %%
cpus
# Out:
# {'CORE I3 8100',
#  'CORE I3 9100F',
#  'CORE I5 7400',
#  'CORE I5 8400',
#  'CORE I5 9400F',
#  'CORE I7 7700',
#  'CORE I7 8700',
#  'Core I3 10100',
#  'Core I3 12100F (DDR5)',
#  'Core I5 10400F',
#  'Core I5 12400F (DDR5)',
#  'Core I7 10700',
#  'PENTIUM G4560',
#  'Ryzen 3 3300X',
#  'Ryzen 5 2600',
#  'Ryzen 5 3400G',
#  'Ryzen 5 3600',
#  'Ryzen 5 5600x',
#  'Ryzen 7 1700',
#  'Ryzen 7 2700',
#  'Ryzen 7 3800X'}
